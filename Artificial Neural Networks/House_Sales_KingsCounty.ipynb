# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
kc_df=pd.read_csv('kc_house_data.csv')

# %%
kc_df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
kc_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
kc_df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
kc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
kc_df['date']=pd.to_datetime(kc_df['date'])

kc_df['Year']=kc_df['date'].apply(lambda x:x.year)

kc_df['Month']=kc_df['date'].apply(lambda x:x.month)

# %%
kc_df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  Year  \
# ...

# %%
sns.histplot(kc_df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.countplot(x=kc_df['bedrooms'])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
sns.countplot(x='Year',data=kc_df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
kc_df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# id              -0.016762
# Month           -0.010081
# Year             0.003576
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='price',y='sqft_living',data=kc_df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='bedrooms',y='price',data=kc_df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
kc_df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'Year', 'Month'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='price',y='lat',data=kc_df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='price',y='long',data=kc_df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=kc_df,hue='price')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
len(kc_df)*0.01
# Out:
# 216.13

# %%
nontop_data=kc_df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=nontop_data,hue='price',palette='RdYlGn',alpha=0.6)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='waterfront',y='price',data=kc_df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x='view',y='price',data=kc_df)
# Out:
# <AxesSubplot:xlabel='view', ylabel='price'>

# %%
sns.countplot(x='Month',data=kc_df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %%
kc_df.groupby('Year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
kc_df.groupby('Month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
kc_df.drop('date',axis=1,inplace=True)

# %%
kc_df.drop(['id','zipcode'],axis=1,inplace=True)

# %%
X=kc_df.drop('price',axis=1).values
y=kc_df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15129, 19)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.optimizers import Adam

# %%
model=Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train,validation_data=(X_test,y_test),batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 6ms/step - loss: 423629127680.0000 - val_loss: 433023516672.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 4ms/step - loss: 422501842944.0000 - val_loss: 428710887424.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 3ms/step - loss: 403522912256.0000 - val_loss: 382807080960.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 4ms/step - loss: 308098859008.0000 - val_loss: 230703529984.0000
# Epoch 5/400
# 119/119 [==============================] - 1s 4ms/step - loss: 149635104768.0000 - val_loss: 109672931328.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 4ms/step - loss: 99086614528.0000 - val_loss: 102460301312.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 4ms/step - loss: 96554319872.0000 - val_loss: 100662288384.0000
# Epoch 8/400
# ...

# %%
loss_df=pd.DataFrame(model.history.history)

# %%
loss_df.head()
# Out:
#            loss      val_loss
# 0  4.236291e+11  4.330235e+11
# 1  4.225018e+11  4.287109e+11
# 2  4.035229e+11  3.828071e+11
# 3  3.080989e+11  2.307035e+11
# 4  1.496351e+11  1.096729e+11

# %%
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
predictions=model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 970us/step

# %%
predictions
# Out:
# array([[519515.72],
#        [647104.7 ],
#        [517738.8 ],
#        ...,
#        [415288.12],
#        [213721.84],
#        [997663.1 ]], dtype=float32)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 104435.29324707935

# %%
mean_squared_error(y_test,predictions)
# Out:
# 28020307998.912468

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 167392.67606114811

# %%
plt.figure(figsize=(10,4))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %%
errors = y_test.reshape(6484, 1) - predictions
sns.histplot(errors)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
test=kc_df.drop('price',axis=1).iloc[0]

# %%
test=scaler.transform(test.values.reshape(-1,19))

# %%
test
# Out:
# array([[0.27272727, 0.125     , 0.06716981, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.5       , 0.09758772,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00573322, 0.        , 0.81818182]])

# %%
test1=kc_df.drop('price',axis=1).iloc[0]

# %%
test1=scaler.transform(test1.values.reshape(1,19))

# %%
test
# Out:
# array([[0.27272727, 0.125     , 0.06716981, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.5       , 0.09758772,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00573322, 0.        , 0.81818182]])

# %%
model.predict(test)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# array([[286590.62]], dtype=float32)

# %%
kc_df['price'].iloc[0]
# Out:
# 221900.0
